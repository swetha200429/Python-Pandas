# %%
import pandas as pd
df=pd.read_csv("patients.csv")
print("Original Data\n")
print(df)
print("\nDrop rows with empty cells\n")
print(df.dropna())
df["Age"]=df["Age"].fillna(0)
df["City"]=df["City"].fillna("Unknown")
print("\nAfter filling empty cells\n")
print(df)
# Out:
# Original Data
#
#    PatientID   Name  Age       City  BillAmount
# 0          1   Ravi   25    Chennai        5000
# 1          2   Sita   27     Mumbai        3000
# 2          3   Arun   30    Chennai        4000
# 3          4  Meena   28      Delhi        2000
# 4          5  Kiran   35  Hyderabad        3500
#
# Drop rows with empty cells
#
#    PatientID   Name  Age       City  BillAmount
# 0          1   Ravi   25    Chennai        5000
# 1          2   Sita   27     Mumbai        3000
# 2          3   Arun   30    Chennai        4000
# 3          4  Meena   28      Delhi        2000
# 4          5  Kiran   35  Hyderabad        3500
#
# After filling empty cells
#
#    PatientID   Name  Age       City  BillAmount
# 0          1   Ravi   25    Chennai        5000
# 1          2   Sita   27     Mumbai        3000
# 2          3   Arun   30    Chennai        4000
# 3          4  Meena   28      Delhi        2000
# 4          5  Kiran   35  Hyderabad        3500

# %%
import pandas as pd
df=pd.read_csv("gym.csv")
print("original Data\n")
print(df)
print("\nData types before\n")
print(df.dtypes)
df["JoinDate"]=pd.to_datetime(df["JoinDate"])
print("\nData types after\n")
print(df.dtypes)
print("\nCleaned Data\n")
print(df)
# Out:
# original Data
#
#    MemberID  Name    JoinDate   Fee
# 0         1   raj  10-01-2014  1000
# 1         2  Asha  10-02-2024  1200
# 2         3  John  04-03-2024   900
# 3         4  Rani  01-04-2024  1100
# 4         5   Ali  12-05-2024  1000
#
# Data types before
#
# MemberID     int64
# Name        object
# JoinDate    object
# Fee          int64
# dtype: object
#
# Data types after
#
# MemberID             int64
# Name                object
# JoinDate    datetime64[ns]
# Fee                  int64
# dtype: object
#
# Cleaned Data
#
#    MemberID  Name   JoinDate   Fee
# 0         1   raj 2014-10-01  1000
# 1         2  Asha 2024-10-02  1200
# 2         3  John 2024-04-03   900
# 3         4  Rani 2024-01-04  1100
# 4         5   Ali 2024-12-05  1000
