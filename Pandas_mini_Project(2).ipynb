# %%
import pandas as pd
df=pd.read_json("mobiles.json")
print("Full Data\n")
print(df)
print("\nFirst 2 rows\n")
print(df.head(2))
print("\nBrand column\n")
print(df["Brand"])
print("\nPrice>20000\n")
print(df[df["Price"]>20000])
print("\nShape\n")
print(df.shape)
# Out:
# Full Data
#
#      Brand      Model  Price  Stock
# 0  Samsung        M31  18000     10
# 1    Apple   iPhone11  50000      5
# 2   Realme      Narzo  15000      8
# 3  OnePlus       Nord  30000      6
# 4   Xiaomi  RedmiNote  12000     15
#
# First 2 rows
#
#      Brand     Model  Price  Stock
# 0  Samsung       M31  18000     10
# 1    Apple  iPhone11  50000      5
#
# Brand column
#
# 0    Samsung
# 1      Apple
# 2     Realme
# 3    OnePlus
# 4     Xiaomi
# Name: Brand, dtype: object
#
# Price>20000
#
#      Brand     Model  Price  Stock
# 1    Apple  iPhone11  50000      5
# 3  OnePlus      Nord  30000      6
#
# Shape
#
# (5, 4)

# %%
import pandas as pd
df=pd.read_csv("orders.csv")
print("First 5 row\n")
print(df.head())
print("\nLast 3 rows\n")
print(df.tail(3))
print("\nInfo\n")
print(df.info())
print("\nDescribe\n")
print(df.describe())
print("\nShape\n")
print(df.shape)
print("\nColumns\n")
print(df.columns)
# Out:
# First 5 row
#
#    OrderID     Food  Price  Quantity       City
# 0        1    Pizza    250         2    Chennai
# 1        2   Burger    120         1     Mumbai
# 2        3  Biryani    200         3  Hyderabad
# 3        4     Dosa     80         4    Chennai
# 4        5  Noodles    150         2  Bangalore
#
# Last 3 rows
#
#    OrderID       Food  Price  Quantity       City
# 4        5    Noodles    150         2  Bangalore
# 5        6    Parotta     90         5    Madurai
# 6        7  FriedRice    180         2      Delhi
#
# Info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   7 non-null      int64
#  1   Food      7 non-null      object
#  2   Price     7 non-null      int64
#  3   Quantity  7 non-null      int64
#  4   City      7 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 412.0+ bytes
# None
# ...
